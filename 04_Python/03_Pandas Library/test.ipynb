# %%
import pandas as pd
df = pd.read_csv('tennis.csv')
df.head()
# Out:
#     Outlook Temperature Humidity    Wind Play Tennis
# 0     Sunny         Hot     High    Weak          No
# 1     Sunny         Hot     High  Strong          No
# 2  Overcast         Hot     High    Weak         Yes
# 3      Rain        Mild     High    Weak         Yes
# 4      Rain        Cool   Normal    Weak         Yes

# %%
df['Outlook'].value_counts()
# Out:
# Outlook
# Sunny       5
# Rain        5
# Overcast    4
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#     Outlook  Temperature  Humidity   Wind  Play Tennis
# 0     False        False     False  False        False
# 1     False        False     False  False        False
# 2     False        False     False  False        False
# 3     False        False     False  False        False
# 4     False        False     False  False        False
# 5     False        False     False  False        False
# 6     False        False     False  False        False
# 7     False        False     False  False        False
# 8     False        False     False  False        False
# 9     False        False     False  False        False
# 10    False        False     False  False        False
# 11    False        False     False  False        False
# 12    False        False     False  False        False
# 13    False        False     False  False        False

# %%
df['Outlook']=df['Outlook'].map({"Sunny":'1',"Rain":"2"})
df
# Out:
#    Outlook Temperature Humidity    Wind Play Tennis
# 0        1         Hot     High    Weak          No
# 1        1         Hot     High  Strong          No
# 2      NaN         Hot     High    Weak         Yes
# 3        2        Mild     High    Weak         Yes
# 4        2        Cool   Normal    Weak         Yes
# 5        2        Cool   Normal  Strong          No
# 6      NaN        Cool   Normal  Strong         Yes
# 7        1        Mild     High    Weak          No
# 8        1        Cool   Normal    Weak         Yes
# 9        2        Mild   Normal    Weak         Yes
# 10       1        Mild   Normal  Strong         Yes
# 11     NaN        Mild     High  Strong         Yes
# 12     NaN         Hot   Normal    Weak         Yes
# 13       2        Mild     High  Strong          No
